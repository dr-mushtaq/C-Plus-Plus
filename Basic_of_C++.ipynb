# %% [markdown]
# <a href="https://colab.research.google.com/github/hussain0048/C-/blob/master/Basic_of_C%2B%2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get --purge remove cuda nvidia* libnvidia-*
# !dpkg -l | grep cuda- | awk '{print $2}' | xargs -n1 dpkg --purge
# !apt-get remove cuda-*
# !apt autoremove
# !apt-get update

# %%
# !wget https://developer.nvidia.com/compute/cuda/9.2/Prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64 -O cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb
# !dpkg -i cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb
# !apt-key add /var/cuda-repo-9-2-local/7fa2af80.pub
# !apt-get update
# !apt-get install cuda-9.2
# Out:
# --2020-08-14 08:24:12--  https://developer.nvidia.com/compute/cuda/9.2/Prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64
# Resolving developer.nvidia.com (developer.nvidia.com)... 152.199.16.29
# Connecting to developer.nvidia.com (developer.nvidia.com)|152.199.16.29|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://developer.download.nvidia.com/compute/cuda/9.2/secure/Prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb?5JbO98donmNSoVxd4nGkhLlZfy_ZcB-zwOddodWSjDYo7jIzx8gC1kscjiVGafLxpUMkv1AR-RNZiDb9Z1c3QL6CZ9nnzRiGEBhq2XV0OS-DT_-5FfKmmoDJ1UgY9HB3SEJm4ecEqU8bJhCPIkhcX7259X7fZbxK6awlYY3rE9cGbXN6J83VGdCWxZb2xh24P80mtP3-T6WqX4O6fLA [following]
# --2020-08-14 08:24:12--  https://developer.download.nvidia.com/compute/cuda/9.2/secure/Prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb?5JbO98donmNSoVxd4nGkhLlZfy_ZcB-zwOddodWSjDYo7jIzx8gC1kscjiVGafLxpUMkv1AR-RNZiDb9Z1c3QL6CZ9nnzRiGEBhq2XV0OS-DT_-5FfKmmoDJ1UgY9HB3SEJm4ecEqU8bJhCPIkhcX7259X7fZbxK6awlYY3rE9cGbXN6J83VGdCWxZb2xh24P80mtP3-T6WqX4O6fLA
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.20.126
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.20.126|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1267391958 (1.2G) [application/x-deb]
# Saving to: ‘cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb’
#
# cuda-repo-ubuntu160 100%[===================>]   1.18G   224MB/s    in 5.5s
#
# 2020-08-14 08:24:18 (218 MB/s) - ‘cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb’ saved [1267391958/1267391958]
#
# Selecting previously unselected package cuda-repo-ubuntu1604-9-2-local.
# (Reading database ... 118903 files and directories currently installed.)
# Preparing to unpack cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb ...
# Unpacking cuda-repo-ubuntu1604-9-2-local (9.2.88-1) ...
# Setting up cuda-repo-ubuntu1604-9-2-local (9.2.88-1) ...
# OK
# Get:1 file:/var/cuda-repo-9-2-local  InRelease
# Ign:1 file:/var/cuda-repo-9-2-local  InRelease
# Get:2 file:/var/cuda-repo-9-2-local  Release [574 B]
# Get:2 file:/var/cuda-repo-9-2-local  Release [574 B]
# Get:3 file:/var/cuda-repo-9-2-local  Release.gpg [819 B]
# Get:3 file:/var/cuda-repo-9-2-local  Release.gpg [819 B]
# Hit:4 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:5 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:7 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Ign:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:11 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease
# Get:12 file:/var/cuda-repo-9-2-local  Packages [18.7 kB]
# Ign:13 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:14 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:15 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'cuda-9-2' for regex 'cuda-9.2'
# Note, selecting 'libcuda-9.2-1' for regex 'cuda-9.2'
# The following additional packages will be installed:
#   cuda-command-line-tools-9-2 cuda-compiler-9-2 cuda-cublas-9-2
#   cuda-cublas-dev-9-2 cuda-cudart-9-2 cuda-cudart-dev-9-2 cuda-cufft-9-2
#   cuda-cufft-dev-9-2 cuda-cuobjdump-9-2 cuda-cupti-9-2 cuda-curand-9-2
#   cuda-curand-dev-9-2 cuda-cusolver-9-2 cuda-cusolver-dev-9-2
#   cuda-cusparse-9-2 cuda-cusparse-dev-9-2 cuda-demo-suite-9-2
#   cuda-documentation-9-2 cuda-driver-dev-9-2 cuda-drivers cuda-drivers-450
#   cuda-gdb-9-2 cuda-gpu-library-advisor-9-2 cuda-libraries-9-2
#   cuda-libraries-dev-9-2 cuda-license-9-2 cuda-memcheck-9-2
#   cuda-misc-headers-9-2 cuda-npp-9-2 cuda-npp-dev-9-2 cuda-nsight-9-2
#   cuda-nvcc-9-2 cuda-nvdisasm-9-2 cuda-nvgraph-9-2 cuda-nvgraph-dev-9-2
#   cuda-nvml-dev-9-2 cuda-nvprof-9-2 cuda-nvprune-9-2 cuda-nvrtc-9-2
#   cuda-nvrtc-dev-9-2 cuda-nvtx-9-2 cuda-nvvp-9-2 cuda-runtime-9-2
#   cuda-samples-9-2 cuda-toolkit-9-2 cuda-tools-9-2 cuda-visual-tools-9-2
#   default-jre dkms dmsetup fakeroot fonts-dejavu-core fonts-dejavu-extra
#   freeglut3 freeglut3-dev keyboard-configuration libargon2-0
#   libatk-wrapper-java libatk-wrapper-java-jni libcap2 libcryptsetup12
#   libdevmapper1.02.1 libfakeroot libfontenc1 libgail-common libgail18
#   libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libidn11 libip4tc0 libjansson4
#   libnss-systemd libnvidia-cfg1-450 libnvidia-common-450 libnvidia-compute-450
#   libnvidia-decode-450 libnvidia-encode-450 libnvidia-extra-450
#   libnvidia-fbc1-450 libnvidia-gl-450 libnvidia-ifr1-450 libpam-systemd
#   libpolkit-agent-1-0 libpolkit-backend-1-0 libpolkit-gobject-1-0 libsystemd0
#   libudev1 libxfont2 libxi-dev libxkbfile1 libxmu-dev libxmu-headers
#   libxnvctrl0 libxxf86dga1 networkd-dispatcher nvidia-compute-utils-450
#   nvidia-dkms-450 nvidia-driver-450 nvidia-kernel-common-450
#   nvidia-kernel-source-450 nvidia-modprobe nvidia-prime nvidia-settings
#   nvidia-utils-450 openjdk-11-jre policykit-1 policykit-1-gnome python3-xkit
#   screen-resolution-extra systemd systemd-sysv udev x11-utils x11-xkb-utils
#   xfonts-base xfonts-encodings xfonts-utils xserver-common
#   xserver-xorg-core-hwe-18.04 xserver-xorg-video-nvidia-450
# Suggested packages:
#   python3-apport menu gvfs iw | wireless-tools systemd-container mesa-utils
#   xfs | xserver xfonts-100dpi | xfonts-75dpi xfonts-scalable
# Recommended packages:
#   libnvidia-compute-450:i386 libnvidia-decode-450:i386
#   libnvidia-encode-450:i386 libnvidia-ifr1-450:i386 libnvidia-fbc1-450:i386
#   libnvidia-gl-450:i386
# The following NEW packages will be installed:
#   cuda-9-2 cuda-command-line-tools-9-2 cuda-compiler-9-2 cuda-cublas-9-2
#   cuda-cublas-dev-9-2 cuda-cudart-9-2 cuda-cudart-dev-9-2 cuda-cufft-9-2
#   cuda-cufft-dev-9-2 cuda-cuobjdump-9-2 cuda-cupti-9-2 cuda-curand-9-2
#   cuda-curand-dev-9-2 cuda-cusolver-9-2 cuda-cusolver-dev-9-2
#   cuda-cusparse-9-2 cuda-cusparse-dev-9-2 cuda-demo-suite-9-2
#   cuda-documentation-9-2 cuda-driver-dev-9-2 cuda-drivers cuda-drivers-450
#   cuda-gdb-9-2 cuda-gpu-library-advisor-9-2 cuda-libraries-9-2
#   cuda-libraries-dev-9-2 cuda-license-9-2 cuda-memcheck-9-2
#   cuda-misc-headers-9-2 cuda-npp-9-2 cuda-npp-dev-9-2 cuda-nsight-9-2
#   cuda-nvcc-9-2 cuda-nvdisasm-9-2 cuda-nvgraph-9-2 cuda-nvgraph-dev-9-2
#   cuda-nvml-dev-9-2 cuda-nvprof-9-2 cuda-nvprune-9-2 cuda-nvrtc-9-2
#   cuda-nvrtc-dev-9-2 cuda-nvtx-9-2 cuda-nvvp-9-2 cuda-runtime-9-2
#   cuda-samples-9-2 cuda-toolkit-9-2 cuda-tools-9-2 cuda-visual-tools-9-2
#   default-jre dkms dmsetup fakeroot fonts-dejavu-core fonts-dejavu-extra
#   freeglut3 freeglut3-dev keyboard-configuration libargon2-0
#   libatk-wrapper-java libatk-wrapper-java-jni libcap2 libcryptsetup12
#   libdevmapper1.02.1 libfakeroot libfontenc1 libgail-common libgail18
#   libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libidn11 libip4tc0 libjansson4
#   libnss-systemd libnvidia-cfg1-450 libnvidia-common-450 libnvidia-compute-450
#   libnvidia-decode-450 libnvidia-encode-450 libnvidia-extra-450
#   libnvidia-fbc1-450 libnvidia-gl-450 libnvidia-ifr1-450 libpam-systemd
#   libpolkit-agent-1-0 libpolkit-backend-1-0 libpolkit-gobject-1-0 libxfont2
#   libxi-dev libxkbfile1 libxmu-dev libxmu-headers libxnvctrl0 libxxf86dga1
#   networkd-dispatcher nvidia-compute-utils-450 nvidia-dkms-450
#   nvidia-driver-450 nvidia-kernel-common-450 nvidia-kernel-source-450
#   nvidia-modprobe nvidia-prime nvidia-settings nvidia-utils-450 openjdk-11-jre
#   policykit-1 policykit-1-gnome python3-xkit screen-resolution-extra systemd
#   systemd-sysv udev x11-utils x11-xkb-utils xfonts-base xfonts-encodings
#   xfonts-utils xserver-common xserver-xorg-core-hwe-18.04
#   xserver-xorg-video-nvidia-450
# The following packages will be upgraded:
#   libsystemd0 libudev1
# 2 upgraded, 120 newly installed, 0 to remove and 45 not upgraded.
# Need to get 119 MB/1,265 MB of archives.
# After this operation, 3,089 MB of additional disk space will be used.
# Get:1 file:/var/cuda-repo-9-2-local  cuda-license-9-2 9.2.88-1 [22.0 kB]
# Get:2 file:/var/cuda-repo-9-2-local  cuda-misc-headers-9-2 9.2.88-1 [640 kB]
# Get:3 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-common-450 all 450.57-0ubuntu0~0.18.04.2 [11.3 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsystemd0 amd64 237-3ubuntu10.42 [208 kB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-modprobe 450.51.06-0ubuntu1 [19.7 kB]
# Get:6 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-compute-450 amd64 450.57-0ubuntu0~0.18.04.2 [21.8 MB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libxnvctrl0 450.51.06-0ubuntu1 [21.2 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-settings 450.51.06-0ubuntu1 [919 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 keyboard-configuration all 1.178ubuntu2.9 [369 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcap2 amd64 1:2.25-1.2 [13.0 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libargon2-0 amd64 0~20161029-1.1 [19.9 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libudev1 amd64 237-3ubuntu10.42 [57.4 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdevmapper1.02.1 amd64 2:1.02.145-4.1ubuntu3.18.04.3 [127 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcryptsetup12 amd64 2:2.0.2-1ubuntu1.1 [134 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libidn11 amd64 1.33-2.1ubuntu1.2 [46.6 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libip4tc0 amd64 1.6.1-2ubuntu2 [19.6 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 systemd amd64 237-3ubuntu10.42 [2,914 kB]
# Get:18 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-drivers-450 450.51.06-1 [2,624 B]
# Get:19 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-drivers 450.51.06-1 [2,504 B]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 systemd-sysv amd64 237-3ubuntu10.42 [15.2 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 dmsetup amd64 2:1.02.145-4.1ubuntu3.18.04.3 [74.4 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libnss-systemd amd64 237-3ubuntu10.42 [105 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpam-systemd amd64 237-3ubuntu10.42 [107 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 networkd-dispatcher all 1.7-0ubuntu3.3 [13.3 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 udev amd64 237-3ubuntu10.42 [1,102 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpolkit-gobject-1-0 amd64 0.105-20ubuntu0.18.04.5 [36.4 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 openjdk-11-jre amd64 11.0.8+10-0ubuntu1~18.04.1 [34.4 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 default-jre amd64 2:1.11-68ubuntu1~18.04.1 [1,076 B]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/universe amd64 freeglut3 amd64 2.8.1-3 [73.6 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/universe amd64 freeglut3-dev amd64 2.8.1-3 [124 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxmu-headers all 2:1.1.2-2 [54.3 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxmu-dev amd64 2:1.1.2-2 [49.0 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxi-dev amd64 2:1.7.9-1 [186 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 dkms all 2.3-3ubuntu9.7 [68.1 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxkbfile1 amd64 1:1.0.9-2 [64.6 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 x11-xkb-utils amd64 7.7+3ubuntu0.18.04.1 [160 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xserver-common all 2:1.19.6-1ubuntu4.4 [27.3 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfontenc1 amd64 1:1.1.3-1 [13.9 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxfont2 amd64 1:2.0.3-1 [91.7 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xserver-xorg-core-hwe-18.04 amd64 2:1.20.8-2ubuntu2.2~18.04.1 [1,334 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-xkit all 0.5.0ubuntu2 [18.6 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpolkit-agent-1-0 amd64 0.105-20ubuntu0.18.04.5 [14.9 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpolkit-backend-1-0 amd64 0.105-20ubuntu0.18.04.5 [36.3 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 policykit-1 amd64 0.105-20ubuntu0.18.04.5 [53.5 kB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/main amd64 policykit-1-gnome amd64 0.105-6ubuntu2 [24.0 kB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/main amd64 screen-resolution-extra all 0.17.3 [11.7 kB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-common all 2.24.32-1ubuntu1 [125 kB]
# Get:49 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-0 amd64 2.24.32-1ubuntu1 [1,769 kB]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjansson4 amd64 2.11-1 [29.3 kB]
# Get:51 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfakeroot amd64 1.22-2ubuntu1 [25.9 kB]
# Get:52 http://archive.ubuntu.com/ubuntu bionic/main amd64 fakeroot amd64 1.22-2ubuntu1 [62.3 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-dejavu-core all 2.37-1 [1,041 kB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-dejavu-extra all 2.37-1 [1,953 kB]
# Get:55 file:/var/cuda-repo-9-2-local  cuda-nvcc-9-2 9.2.88-1 [15.4 MB]
# Get:56 file:/var/cuda-repo-9-2-local  cuda-cuobjdump-9-2 9.2.88-1 [129 kB]
# Get:57 file:/var/cuda-repo-9-2-local  cuda-nvprune-9-2 9.2.88-1 [36.7 kB]
# Get:58 file:/var/cuda-repo-9-2-local  cuda-compiler-9-2 9.2.88-1 [2,518 B]
# Get:59 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11-utils amd64 7.7+3build1 [196 kB]
# Get:60 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk-wrapper-java all 0.33.3-20ubuntu0.1 [34.7 kB]
# Get:61 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk-wrapper-java-jni amd64 0.33.3-20ubuntu0.1 [28.3 kB]
# Get:62 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail18 amd64 2.24.32-1ubuntu1 [14.2 kB]
# Get:63 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail-common amd64 2.24.32-1ubuntu1 [112 kB]
# Get:64 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-bin amd64 2.24.32-1ubuntu1 [7,536 B]
# Get:65 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 nvidia-prime all 0.8.8.2 [8,412 B]
# Get:66 http://archive.ubuntu.com/ubuntu bionic/main amd64 xfonts-encodings all 1:1.0.4-2 [573 kB]
# Get:67 http://archive.ubuntu.com/ubuntu bionic/main amd64 xfonts-utils amd64 1:7.7+6 [91.5 kB]
# Get:68 http://archive.ubuntu.com/ubuntu bionic/main amd64 xfonts-base all 1:1.0.4+nmu1 [5,914 kB]
# Get:69 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-decode-450 amd64 450.57-0ubuntu0~0.18.04.2 [1,105 kB]
# Get:70 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-encode-450 amd64 450.57-0ubuntu0~0.18.04.2 [40.7 kB]
# Get:71 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-fbc1-450 amd64 450.57-0ubuntu0~0.18.04.2 [51.0 kB]
# Get:72 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-gl-450 amd64 450.57-0ubuntu0~0.18.04.2 [60.5 MB]
# Get:73 file:/var/cuda-repo-9-2-local  cuda-nvdisasm-9-2 9.2.88-1 [17.4 MB]
# Get:74 file:/var/cuda-repo-9-2-local  cuda-gdb-9-2 9.2.88-1 [2,765 kB]
# Get:75 file:/var/cuda-repo-9-2-local  cuda-nvprof-9-2 9.2.88-1 [4,737 kB]
# Get:76 file:/var/cuda-repo-9-2-local  cuda-memcheck-9-2 9.2.88-1 [137 kB]
# Get:77 file:/var/cuda-repo-9-2-local  cuda-cudart-9-2 9.2.88-1 [97.8 kB]
# Get:78 file:/var/cuda-repo-9-2-local  cuda-driver-dev-9-2 9.2.88-1 [11.1 kB]
# Get:79 file:/var/cuda-repo-9-2-local  cuda-cudart-dev-9-2 9.2.88-1 [718 kB]
# Get:80 file:/var/cuda-repo-9-2-local  cuda-cupti-9-2 9.2.88-1 [1,537 kB]
# Get:81 file:/var/cuda-repo-9-2-local  cuda-gpu-library-advisor-9-2 9.2.88-1 [1,002 kB]
# Get:82 file:/var/cuda-repo-9-2-local  cuda-nvtx-9-2 9.2.88-1 [24.3 kB]
# Get:83 file:/var/cuda-repo-9-2-local  cuda-command-line-tools-9-2 9.2.88-1 [26.3 kB]
# Get:84 file:/var/cuda-repo-9-2-local  cuda-nsight-9-2 9.2.88-1 [2,580 B]
# Get:85 file:/var/cuda-repo-9-2-local  cuda-nvvp-9-2 9.2.88-1 [2,528 B]
# Get:86 file:/var/cuda-repo-9-2-local  cuda-nvrtc-9-2 9.2.88-1 [5,908 kB]
# Get:87 file:/var/cuda-repo-9-2-local  cuda-nvrtc-dev-9-2 9.2.88-1 [9,318 B]
# Get:88 file:/var/cuda-repo-9-2-local  cuda-cusolver-9-2 9.2.88-1 [31.1 MB]
# Get:89 file:/var/cuda-repo-9-2-local  cuda-cusolver-dev-9-2 9.2.88-1 [8,184 kB]
# Get:90 file:/var/cuda-repo-9-2-local  cuda-cublas-9-2 9.2.88-1 [24.9 MB]
# Get:91 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-ifr1-450 amd64 450.57-0ubuntu0~0.18.04.2 [69.7 kB]
# Get:92 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 nvidia-compute-utils-450 amd64 450.57-0ubuntu0~0.18.04.2 [124 kB]
# Get:93 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 nvidia-kernel-source-450 amd64 450.57-0ubuntu0~0.18.04.2 [11.8 MB]
# Get:94 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 nvidia-kernel-common-450 amd64 450.57-0ubuntu0~0.18.04.2 [20.7 kB]
# Get:95 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 nvidia-dkms-450 amd64 450.57-0ubuntu0~0.18.04.2 [30.5 kB]
# Get:96 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-extra-450 amd64 450.57-0ubuntu0~0.18.04.2 [40.8 kB]
# Get:97 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 nvidia-utils-450 amd64 450.57-0ubuntu0~0.18.04.2 [367 kB]
# Get:98 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-cfg1-450 amd64 450.57-0ubuntu0~0.18.04.2 [76.4 kB]
# Get:99 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 xserver-xorg-video-nvidia-450 amd64 450.57-0ubuntu0~0.18.04.2 [1,534 kB]
# Get:100 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 nvidia-driver-450 amd64 450.57-0ubuntu0~0.18.04.2 [433 kB]
# Get:101 file:/var/cuda-repo-9-2-local  cuda-cublas-dev-9-2 9.2.88-1 [49.1 MB]
# Get:102 file:/var/cuda-repo-9-2-local  cuda-cufft-9-2 9.2.88-1 [51.5 MB]
# Get:103 file:/var/cuda-repo-9-2-local  cuda-cufft-dev-9-2 9.2.88-1 [106 MB]
# Get:104 file:/var/cuda-repo-9-2-local  cuda-curand-9-2 9.2.88-1 [38.8 MB]
# Get:105 file:/var/cuda-repo-9-2-local  cuda-curand-dev-9-2 9.2.88-1 [57.8 MB]
# Get:106 file:/var/cuda-repo-9-2-local  cuda-cusparse-9-2 9.2.88-1 [27.6 MB]
# Get:107 file:/var/cuda-repo-9-2-local  cuda-cusparse-dev-9-2 9.2.88-1 [27.8 MB]
# Get:108 file:/var/cuda-repo-9-2-local  cuda-npp-9-2 9.2.88-1 [52.1 MB]
# Get:109 file:/var/cuda-repo-9-2-local  cuda-npp-dev-9-2 9.2.88-1 [52.0 MB]
# Get:110 file:/var/cuda-repo-9-2-local  cuda-nvml-dev-9-2 9.2.88-1 [49.4 kB]
# Get:111 file:/var/cuda-repo-9-2-local  cuda-nvgraph-9-2 9.2.88-1 [11.7 MB]
# Get:112 file:/var/cuda-repo-9-2-local  cuda-nvgraph-dev-9-2 9.2.88-1 [30.0 MB]
# Get:113 file:/var/cuda-repo-9-2-local  cuda-visual-tools-9-2 9.2.88-1 [396 MB]
# Get:114 file:/var/cuda-repo-9-2-local  cuda-tools-9-2 9.2.88-1 [2,486 B]
# Get:115 file:/var/cuda-repo-9-2-local  cuda-samples-9-2 9.2.88-1 [76.3 MB]
# Get:116 file:/var/cuda-repo-9-2-local  cuda-documentation-9-2 9.2.88-1 [50.4 MB]
# Get:117 file:/var/cuda-repo-9-2-local  cuda-libraries-dev-9-2 9.2.88-1 [2,598 B]
# Get:118 file:/var/cuda-repo-9-2-local  cuda-toolkit-9-2 9.2.88-1 [2,828 B]
# Get:119 file:/var/cuda-repo-9-2-local  cuda-libraries-9-2 9.2.88-1 [2,568 B]
# Get:120 file:/var/cuda-repo-9-2-local  cuda-runtime-9-2 9.2.88-1 [2,530 B]
# Get:121 file:/var/cuda-repo-9-2-local  cuda-demo-suite-9-2 9.2.88-1 [3,889 kB]
# Get:122 file:/var/cuda-repo-9-2-local  cuda-9-2 9.2.88-1 [2,560 B]
# Fetched 119 MB in 20s (6,003 kB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# (Reading database ... 118976 files and directories currently installed.)
# Preparing to unpack .../libsystemd0_237-3ubuntu10.42_amd64.deb ...
# Unpacking libsystemd0:amd64 (237-3ubuntu10.42) over (237-3ubuntu10.41) ...
# Setting up libsystemd0:amd64 (237-3ubuntu10.42) ...
# Selecting previously unselected package keyboard-configuration.
# (Reading database ... 118976 files and directories currently installed.)
# Preparing to unpack .../keyboard-configuration_1.178ubuntu2.9_all.deb ...
# Unpacking keyboard-configuration (1.178ubuntu2.9) ...
# Selecting previously unselected package libcap2:amd64.
# Preparing to unpack .../libcap2_1%3a2.25-1.2_amd64.deb ...
# Unpacking libcap2:amd64 (1:2.25-1.2) ...
# Selecting previously unselected package libargon2-0:amd64.
# Preparing to unpack .../libargon2-0_0~20161029-1.1_amd64.deb ...
# Unpacking libargon2-0:amd64 (0~20161029-1.1) ...
# Preparing to unpack .../libudev1_237-3ubuntu10.42_amd64.deb ...
# Unpacking libudev1:amd64 (237-3ubuntu10.42) over (237-3ubuntu10.41) ...
# Setting up libudev1:amd64 (237-3ubuntu10.42) ...
# Selecting previously unselected package libdevmapper1.02.1:amd64.
# (Reading database ... 119008 files and directories currently installed.)
# Preparing to unpack .../libdevmapper1.02.1_2%3a1.02.145-4.1ubuntu3.18.04.3_amd64.deb ...
# Unpacking libdevmapper1.02.1:amd64 (2:1.02.145-4.1ubuntu3.18.04.3) ...
# Selecting previously unselected package libcryptsetup12:amd64.
# Preparing to unpack .../libcryptsetup12_2%3a2.0.2-1ubuntu1.1_amd64.deb ...
# Unpacking libcryptsetup12:amd64 (2:2.0.2-1ubuntu1.1) ...
# Selecting previously unselected package libidn11:amd64.
# Preparing to unpack .../libidn11_1.33-2.1ubuntu1.2_amd64.deb ...
# Unpacking libidn11:amd64 (1.33-2.1ubuntu1.2) ...
# Selecting previously unselected package libip4tc0:amd64.
# Preparing to unpack .../libip4tc0_1.6.1-2ubuntu2_amd64.deb ...
# Unpacking libip4tc0:amd64 (1.6.1-2ubuntu2) ...
# Setting up libcap2:amd64 (1:2.25-1.2) ...
# Setting up libargon2-0:amd64 (0~20161029-1.1) ...
# Setting up libdevmapper1.02.1:amd64 (2:1.02.145-4.1ubuntu3.18.04.3) ...
# Setting up libcryptsetup12:amd64 (2:2.0.2-1ubuntu1.1) ...
# Setting up libidn11:amd64 (1.33-2.1ubuntu1.2) ...
# Setting up libip4tc0:amd64 (1.6.1-2ubuntu2) ...
# Selecting previously unselected package systemd.
# (Reading database ... 119028 files and directories currently installed.)
# Preparing to unpack .../systemd_237-3ubuntu10.42_amd64.deb ...
# Unpacking systemd (237-3ubuntu10.42) ...
# Setting up systemd (237-3ubuntu10.42) ...
# Selecting previously unselected package systemd-sysv.
# (Reading database ... 119710 files and directories currently installed.)
# Preparing to unpack .../000-systemd-sysv_237-3ubuntu10.42_amd64.deb ...
# Unpacking systemd-sysv (237-3ubuntu10.42) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../001-libxxf86dga1_2%3a1.1.4-1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.4-1) ...
# Selecting previously unselected package dmsetup.
# Preparing to unpack .../002-dmsetup_2%3a1.02.145-4.1ubuntu3.18.04.3_amd64.deb ...
# Unpacking dmsetup (2:1.02.145-4.1ubuntu3.18.04.3) ...
# Selecting previously unselected package libnss-systemd:amd64.
# Preparing to unpack .../003-libnss-systemd_237-3ubuntu10.42_amd64.deb ...
# Unpacking libnss-systemd:amd64 (237-3ubuntu10.42) ...
# Selecting previously unselected package libpam-systemd:amd64.
# Preparing to unpack .../004-libpam-systemd_237-3ubuntu10.42_amd64.deb ...
# Unpacking libpam-systemd:amd64 (237-3ubuntu10.42) ...
# Selecting previously unselected package networkd-dispatcher.
# Preparing to unpack .../005-networkd-dispatcher_1.7-0ubuntu3.3_all.deb ...
# Unpacking networkd-dispatcher (1.7-0ubuntu3.3) ...
# Selecting previously unselected package udev.
# Preparing to unpack .../006-udev_237-3ubuntu10.42_amd64.deb ...
# Unpacking udev (237-3ubuntu10.42) ...
# Selecting previously unselected package libpolkit-gobject-1-0:amd64.
# Preparing to unpack .../007-libpolkit-gobject-1-0_0.105-20ubuntu0.18.04.5_amd64.deb ...
# Unpacking libpolkit-gobject-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Selecting previously unselected package cuda-license-9-2.
# Preparing to unpack .../008-cuda-license-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-license-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-misc-headers-9-2.
# Preparing to unpack .../009-cuda-misc-headers-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-misc-headers-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvcc-9-2.
# Preparing to unpack .../010-cuda-nvcc-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvcc-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cuobjdump-9-2.
# Preparing to unpack .../011-cuda-cuobjdump-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cuobjdump-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvprune-9-2.
# Preparing to unpack .../012-cuda-nvprune-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvprune-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-compiler-9-2.
# Preparing to unpack .../013-cuda-compiler-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-compiler-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvdisasm-9-2.
# Preparing to unpack .../014-cuda-nvdisasm-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvdisasm-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-gdb-9-2.
# Preparing to unpack .../015-cuda-gdb-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-gdb-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvprof-9-2.
# Preparing to unpack .../016-cuda-nvprof-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvprof-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-memcheck-9-2.
# Preparing to unpack .../017-cuda-memcheck-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-memcheck-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cudart-9-2.
# Preparing to unpack .../018-cuda-cudart-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cudart-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-driver-dev-9-2.
# Preparing to unpack .../019-cuda-driver-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-driver-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cudart-dev-9-2.
# Preparing to unpack .../020-cuda-cudart-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cudart-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cupti-9-2.
# Preparing to unpack .../021-cuda-cupti-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cupti-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-gpu-library-advisor-9-2.
# Preparing to unpack .../022-cuda-gpu-library-advisor-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-gpu-library-advisor-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvtx-9-2.
# Preparing to unpack .../023-cuda-nvtx-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvtx-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-command-line-tools-9-2.
# Preparing to unpack .../024-cuda-command-line-tools-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-command-line-tools-9-2 (9.2.88-1) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../025-openjdk-11-jre_11.0.8+10-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.8+10-0ubuntu1~18.04.1) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../026-default-jre_2%3a1.11-68ubuntu1~18.04.1_amd64.deb ...
# Unpacking default-jre (2:1.11-68ubuntu1~18.04.1) ...
# Selecting previously unselected package cuda-nsight-9-2.
# Preparing to unpack .../027-cuda-nsight-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nsight-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvvp-9-2.
# Preparing to unpack .../028-cuda-nvvp-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvvp-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvrtc-9-2.
# Preparing to unpack .../029-cuda-nvrtc-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvrtc-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-9-2.
# Preparing to unpack .../030-cuda-nvrtc-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cusolver-9-2.
# Preparing to unpack .../031-cuda-cusolver-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cusolver-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cusolver-dev-9-2.
# Preparing to unpack .../032-cuda-cusolver-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cusolver-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cublas-9-2.
# Preparing to unpack .../033-cuda-cublas-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cublas-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cublas-dev-9-2.
# Preparing to unpack .../034-cuda-cublas-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cublas-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cufft-9-2.
# Preparing to unpack .../035-cuda-cufft-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cufft-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cufft-dev-9-2.
# Preparing to unpack .../036-cuda-cufft-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cufft-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-curand-9-2.
# Preparing to unpack .../037-cuda-curand-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-curand-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-curand-dev-9-2.
# Preparing to unpack .../038-cuda-curand-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-curand-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cusparse-9-2.
# Preparing to unpack .../039-cuda-cusparse-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cusparse-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cusparse-dev-9-2.
# Preparing to unpack .../040-cuda-cusparse-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cusparse-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-npp-9-2.
# Preparing to unpack .../041-cuda-npp-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-npp-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-npp-dev-9-2.
# Preparing to unpack .../042-cuda-npp-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-npp-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvml-dev-9-2.
# Preparing to unpack .../043-cuda-nvml-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvml-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvgraph-9-2.
# Preparing to unpack .../044-cuda-nvgraph-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvgraph-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvgraph-dev-9-2.
# Preparing to unpack .../045-cuda-nvgraph-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvgraph-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-visual-tools-9-2.
# Preparing to unpack .../046-cuda-visual-tools-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-visual-tools-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-tools-9-2.
# Preparing to unpack .../047-cuda-tools-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-tools-9-2 (9.2.88-1) ...
# Selecting previously unselected package freeglut3:amd64.
# Preparing to unpack .../048-freeglut3_2.8.1-3_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-3) ...
# Selecting previously unselected package freeglut3-dev:amd64.
# Preparing to unpack .../049-freeglut3-dev_2.8.1-3_amd64.deb ...
# Unpacking freeglut3-dev:amd64 (2.8.1-3) ...
# Selecting previously unselected package libxmu-headers.
# Preparing to unpack .../050-libxmu-headers_2%3a1.1.2-2_all.deb ...
# Unpacking libxmu-headers (2:1.1.2-2) ...
# Selecting previously unselected package libxmu-dev:amd64.
# Preparing to unpack .../051-libxmu-dev_2%3a1.1.2-2_amd64.deb ...
# Unpacking libxmu-dev:amd64 (2:1.1.2-2) ...
# Selecting previously unselected package libxi-dev:amd64.
# Preparing to unpack .../052-libxi-dev_2%3a1.7.9-1_amd64.deb ...
# Unpacking libxi-dev:amd64 (2:1.7.9-1) ...
# Selecting previously unselected package cuda-samples-9-2.
# Preparing to unpack .../053-cuda-samples-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-samples-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-documentation-9-2.
# Preparing to unpack .../054-cuda-documentation-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-documentation-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-libraries-dev-9-2.
# Preparing to unpack .../055-cuda-libraries-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-libraries-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-toolkit-9-2.
# Preparing to unpack .../056-cuda-toolkit-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-toolkit-9-2 (9.2.88-1) ...
# Selecting previously unselected package libnvidia-common-450.
# Preparing to unpack .../057-libnvidia-common-450_450.57-0ubuntu0~0.18.04.2_all.deb ...
# Unpacking libnvidia-common-450 (450.57-0ubuntu0~0.18.04.2) ...
# Selecting previously unselected package libnvidia-compute-450:amd64.
# Preparing to unpack .../058-libnvidia-compute-450_450.57-0ubuntu0~0.18.04.2_amd64.deb ...
# Unpacking libnvidia-compute-450:amd64 (450.57-0ubuntu0~0.18.04.2) ...
# Selecting previously unselected package libnvidia-decode-450:amd64.
# Preparing to unpack .../059-libnvidia-decode-450_450.57-0ubuntu0~0.18.04.2_amd64.deb ...
# Unpacking libnvidia-decode-450:amd64 (450.57-0ubuntu0~0.18.04.2) ...
# Selecting previously unselected package libnvidia-encode-450:amd64.
# Preparing to unpack .../060-libnvidia-encode-450_450.57-0ubuntu0~0.18.04.2_amd64.deb ...
# Unpacking libnvidia-encode-450:amd64 (450.57-0ubuntu0~0.18.04.2) ...
# Selecting previously unselected package libnvidia-fbc1-450:amd64.
# Preparing to unpack .../061-libnvidia-fbc1-450_450.57-0ubuntu0~0.18.04.2_amd64.deb ...
# Unpacking libnvidia-fbc1-450:amd64 (450.57-0ubuntu0~0.18.04.2) ...
# Selecting previously unselected package libnvidia-gl-450:amd64.
# Preparing to unpack .../062-libnvidia-gl-450_450.57-0ubuntu0~0.18.04.2_amd64.deb ...
# Unpacking libnvidia-gl-450:amd64 (450.57-0ubuntu0~0.18.04.2) ...
# Selecting previously unselected package libnvidia-ifr1-450:amd64.
# Preparing to unpack .../063-libnvidia-ifr1-450_450.57-0ubuntu0~0.18.04.2_amd64.deb ...
# Unpacking libnvidia-ifr1-450:amd64 (450.57-0ubuntu0~0.18.04.2) ...
# Selecting previously unselected package nvidia-compute-utils-450.
# Preparing to unpack .../064-nvidia-compute-utils-450_450.57-0ubuntu0~0.18.04.2_amd64.deb ...
# Unpacking nvidia-compute-utils-450 (450.57-0ubuntu0~0.18.04.2) ...
# Selecting previously unselected package dkms.
# Preparing to unpack .../065-dkms_2.3-3ubuntu9.7_all.deb ...
# Unpacking dkms (2.3-3ubuntu9.7) ...
# Selecting previously unselected package nvidia-kernel-source-450.
# Preparing to unpack .../066-nvidia-kernel-source-450_450.57-0ubuntu0~0.18.04.2_amd64.deb ...
# Unpacking nvidia-kernel-source-450 (450.57-0ubuntu0~0.18.04.2) ...
# Selecting previously unselected package nvidia-kernel-common-450.
# Preparing to unpack .../067-nvidia-kernel-common-450_450.57-0ubuntu0~0.18.04.2_amd64.deb ...
# Unpacking nvidia-kernel-common-450 (450.57-0ubuntu0~0.18.04.2) ...
# Selecting previously unselected package nvidia-dkms-450.
# Preparing to unpack .../068-nvidia-dkms-450_450.57-0ubuntu0~0.18.04.2_amd64.deb ...
# Unpacking nvidia-dkms-450 (450.57-0ubuntu0~0.18.04.2) ...
# Selecting previously unselected package libnvidia-extra-450:amd64.
# Preparing to unpack .../069-libnvidia-extra-450_450.57-0ubuntu0~0.18.04.2_amd64.deb ...
# Unpacking libnvidia-extra-450:amd64 (450.57-0ubuntu0~0.18.04.2) ...
# Selecting previously unselected package nvidia-utils-450.
# Preparing to unpack .../070-nvidia-utils-450_450.57-0ubuntu0~0.18.04.2_amd64.deb ...
# Unpacking nvidia-utils-450 (450.57-0ubuntu0~0.18.04.2) ...
# Selecting previously unselected package libnvidia-cfg1-450:amd64.
# Preparing to unpack .../071-libnvidia-cfg1-450_450.57-0ubuntu0~0.18.04.2_amd64.deb ...
# Unpacking libnvidia-cfg1-450:amd64 (450.57-0ubuntu0~0.18.04.2) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../072-libxkbfile1_1%3a1.0.9-2_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.0.9-2) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../073-x11-xkb-utils_7.7+3ubuntu0.18.04.1_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+3ubuntu0.18.04.1) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../074-xserver-common_2%3a1.19.6-1ubuntu4.4_all.deb ...
# Unpacking xserver-common (2:1.19.6-1ubuntu4.4) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../075-libfontenc1_1%3a1.1.3-1_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.3-1) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../076-libxfont2_1%3a2.0.3-1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.3-1) ...
# Selecting previously unselected package xserver-xorg-core-hwe-18.04.
# Preparing to unpack .../077-xserver-xorg-core-hwe-18.04_2%3a1.20.8-2ubuntu2.2~18.04.1_amd64.deb ...
# Unpacking xserver-xorg-core-hwe-18.04 (2:1.20.8-2ubuntu2.2~18.04.1) ...
# Selecting previously unselected package xserver-xorg-video-nvidia-450.
# Preparing to unpack .../078-xserver-xorg-video-nvidia-450_450.57-0ubuntu0~0.18.04.2_amd64.deb ...
# Unpacking xserver-xorg-video-nvidia-450 (450.57-0ubuntu0~0.18.04.2) ...
# Selecting previously unselected package nvidia-driver-450.
# Preparing to unpack .../079-nvidia-driver-450_450.57-0ubuntu0~0.18.04.2_amd64.deb ...
# Unpacking nvidia-driver-450 (450.57-0ubuntu0~0.18.04.2) ...
# Selecting previously unselected package nvidia-modprobe.
# Preparing to unpack .../080-nvidia-modprobe_450.51.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-modprobe (450.51.06-0ubuntu1) ...
# Selecting previously unselected package python3-xkit.
# Preparing to unpack .../081-python3-xkit_0.5.0ubuntu2_all.deb ...
# Unpacking python3-xkit (0.5.0ubuntu2) ...
# Selecting previously unselected package libpolkit-agent-1-0:amd64.
# Preparing to unpack .../082-libpolkit-agent-1-0_0.105-20ubuntu0.18.04.5_amd64.deb ...
# Unpacking libpolkit-agent-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Selecting previously unselected package libpolkit-backend-1-0:amd64.
# Preparing to unpack .../083-libpolkit-backend-1-0_0.105-20ubuntu0.18.04.5_amd64.deb ...
# Unpacking libpolkit-backend-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Selecting previously unselected package policykit-1.
# Preparing to unpack .../084-policykit-1_0.105-20ubuntu0.18.04.5_amd64.deb ...
# Unpacking policykit-1 (0.105-20ubuntu0.18.04.5) ...
# Selecting previously unselected package policykit-1-gnome.
# Preparing to unpack .../085-policykit-1-gnome_0.105-6ubuntu2_amd64.deb ...
# Unpacking policykit-1-gnome (0.105-6ubuntu2) ...
# Selecting previously unselected package screen-resolution-extra.
# Preparing to unpack .../086-screen-resolution-extra_0.17.3_all.deb ...
# Unpacking screen-resolution-extra (0.17.3) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../087-libgtk2.0-common_2.24.32-1ubuntu1_all.deb ...
# Unpacking libgtk2.0-common (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../088-libgtk2.0-0_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libjansson4:amd64.
# Preparing to unpack .../089-libjansson4_2.11-1_amd64.deb ...
# Unpacking libjansson4:amd64 (2.11-1) ...
# Selecting previously unselected package libxnvctrl0:amd64.
# Preparing to unpack .../090-libxnvctrl0_450.51.06-0ubuntu1_amd64.deb ...
# Unpacking libxnvctrl0:amd64 (450.51.06-0ubuntu1) ...
# Selecting previously unselected package nvidia-settings.
# Preparing to unpack .../091-nvidia-settings_450.51.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-settings (450.51.06-0ubuntu1) ...
# Selecting previously unselected package cuda-drivers-450.
# Preparing to unpack .../092-cuda-drivers-450_450.51.06-1_amd64.deb ...
# Unpacking cuda-drivers-450 (450.51.06-1) ...
# Selecting previously unselected package cuda-drivers.
# Preparing to unpack .../093-cuda-drivers_450.51.06-1_amd64.deb ...
# Unpacking cuda-drivers (450.51.06-1) ...
# Selecting previously unselected package cuda-libraries-9-2.
# Preparing to unpack .../094-cuda-libraries-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-libraries-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-runtime-9-2.
# Preparing to unpack .../095-cuda-runtime-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-runtime-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-demo-suite-9-2.
# Preparing to unpack .../096-cuda-demo-suite-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-demo-suite-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-9-2.
# Preparing to unpack .../097-cuda-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-9-2 (9.2.88-1) ...
# Selecting previously unselected package libfakeroot:amd64.
# Preparing to unpack .../098-libfakeroot_1.22-2ubuntu1_amd64.deb ...
# Unpacking libfakeroot:amd64 (1.22-2ubuntu1) ...
# Selecting previously unselected package fakeroot.
# Preparing to unpack .../099-fakeroot_1.22-2ubuntu1_amd64.deb ...
# Unpacking fakeroot (1.22-2ubuntu1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../100-fonts-dejavu-core_2.37-1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../101-fonts-dejavu-extra_2.37-1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-1) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../102-x11-utils_7.7+3build1_amd64.deb ...
# Unpacking x11-utils (7.7+3build1) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../103-libatk-wrapper-java_0.33.3-20ubuntu0.1_all.deb ...
# Unpacking libatk-wrapper-java (0.33.3-20ubuntu0.1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../104-libatk-wrapper-java-jni_0.33.3-20ubuntu0.1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.33.3-20ubuntu0.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../105-libgail18_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../106-libgail-common_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../107-libgtk2.0-bin_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Selecting previously unselected package nvidia-prime.
# Preparing to unpack .../108-nvidia-prime_0.8.8.2_all.deb ...
# Unpacking nvidia-prime (0.8.8.2) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../109-xfonts-encodings_1%3a1.0.4-2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.4-2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../110-xfonts-utils_1%3a7.7+6_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../111-xfonts-base_1%3a1.0.4+nmu1_all.deb ...
# Unpacking xfonts-base (1:1.0.4+nmu1) ...
# Setting up libxkbfile1:amd64 (1:1.0.9-2) ...
# Setting up libnss-systemd:amd64 (237-3ubuntu10.42) ...
# First installation detected...
# Checking NSS setup...
# Setting up freeglut3:amd64 (2.8.1-3) ...
# Setting up keyboard-configuration (1.178ubuntu2.9) ...
# Your console font configuration will be updated the next time your system
# boots. If you want to update it now, run 'setupcon' from a virtual console.
# Setting up libnvidia-extra-450:amd64 (450.57-0ubuntu0~0.18.04.2) ...
# Setting up libgtk2.0-common (2.24.32-1ubuntu1) ...
# Setting up nvidia-prime (0.8.8.2) ...
# Setting up libnvidia-compute-450:amd64 (450.57-0ubuntu0~0.18.04.2) ...
# Setting up x11-xkb-utils (7.7+3ubuntu0.18.04.1) ...
# Setting up fonts-dejavu-core (2.37-1) ...
# Setting up systemd-sysv (237-3ubuntu10.42) ...
# Setting up libxmu-headers (2:1.1.2-2) ...
# Setting up libjansson4:amd64 (2.11-1) ...
# Setting up libnvidia-fbc1-450:amd64 (450.57-0ubuntu0~0.18.04.2) ...
# Setting up cuda-license-9-2 (9.2.88-1) ...
# *** LICENSE AGREEMENT ***
# By using this software you agree to fully comply with the terms and
# conditions of the EULA (End User License Agreement). The EULA is located
# at /usr/local/cuda-9.2/doc/EULA.txt. The EULA can also be found at
# http://docs.nvidia.com/cuda/eula/index.html. If you do not agree to the
# terms and conditions of the EULA, do not use the software.
#
# Setting up xfonts-encodings (1:1.0.4-2) ...
# Setting up nvidia-utils-450 (450.57-0ubuntu0~0.18.04.2) ...
# Setting up nvidia-kernel-common-450 (450.57-0ubuntu0~0.18.04.2) ...
# Setting up cuda-nvprune-9-2 (9.2.88-1) ...
# Setting up dkms (2.3-3ubuntu9.7) ...
# Setting up libxxf86dga1:amd64 (2:1.1.4-1) ...
# Setting up udev (237-3ubuntu10.42) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of restart.
# Setting up cuda-cudart-9-2 (9.2.88-1) ...
# Setting up libfakeroot:amd64 (1.22-2ubuntu1) ...
# Setting up nvidia-modprobe (450.51.06-0ubuntu1) ...
# Setting up cuda-nvprof-9-2 (9.2.88-1) ...
# Setting up cuda-nvrtc-9-2 (9.2.88-1) ...
# Setting up cuda-nvtx-9-2 (9.2.88-1) ...
# Setting up nvidia-kernel-source-450 (450.57-0ubuntu0~0.18.04.2) ...
# Setting up libfontenc1:amd64 (1:1.1.3-1) ...
# Setting up libnvidia-cfg1-450:amd64 (450.57-0ubuntu0~0.18.04.2) ...
# Setting up dmsetup (2:1.02.145-4.1ubuntu3.18.04.3) ...
# Setting up nvidia-dkms-450 (450.57-0ubuntu0~0.18.04.2) ...
# Loading new nvidia-450.57 DKMS files...
# It is likely that 4.19.112+ belongs to a chroot's host
# Building for 4.15.0-112-generic
# Building for architecture x86_64
# Building initial module for 4.15.0-112-generic
# Done.
#
# nvidia:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-112-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-112-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-112-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-112-generic/updates/dkms/
#
# depmod...
#
# DKMS: install completed.
# Setting up nvidia-compute-utils-450 (450.57-0ubuntu0~0.18.04.2) ...
# Warning: The home dir /nonexistent you specified can't be accessed: No such file or directory
# Adding system user `nvidia-persistenced' (UID 103) ...
# Adding new group `nvidia-persistenced' (GID 107) ...
# Adding new user `nvidia-persistenced' (UID 103) with group `nvidia-persistenced' ...
# Not creating home directory `/nonexistent'.
# Setting up libxi-dev:amd64 (2:1.7.9-1) ...
# Setting up cuda-cusolver-9-2 (9.2.88-1) ...
# Setting up fonts-dejavu-extra (2.37-1) ...
# Setting up cuda-nvml-dev-9-2 (9.2.88-1) ...
# Setting up libnvidia-common-450 (450.57-0ubuntu0~0.18.04.2) ...
# Setting up freeglut3-dev:amd64 (2.8.1-3) ...
# Setting up libxnvctrl0:amd64 (450.51.06-0ubuntu1) ...
# Setting up cuda-cufft-9-2 (9.2.88-1) ...
# Setting up networkd-dispatcher (1.7-0ubuntu3.3) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/networkd-dispatcher.service → /lib/systemd/system/networkd-dispatcher.service.
# Setting up libpolkit-gobject-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Setting up python3-xkit (0.5.0ubuntu2) ...
# Setting up openjdk-11-jre:amd64 (11.0.8+10-0ubuntu1~18.04.1) ...
# Setting up cuda-npp-9-2 (9.2.88-1) ...
# Setting up cuda-misc-headers-9-2 (9.2.88-1) ...
# Setting up cuda-memcheck-9-2 (9.2.88-1) ...
# Setting up libnvidia-decode-450:amd64 (450.57-0ubuntu0~0.18.04.2) ...
# Setting up cuda-npp-dev-9-2 (9.2.88-1) ...
# Setting up libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Setting up xserver-common (2:1.19.6-1ubuntu4.4) ...
# Setting up cuda-nvdisasm-9-2 (9.2.88-1) ...
# Setting up libpam-systemd:amd64 (237-3ubuntu10.42) ...
# Setting up libnvidia-encode-450:amd64 (450.57-0ubuntu0~0.18.04.2) ...
# Setting up cuda-nvrtc-dev-9-2 (9.2.88-1) ...
# Setting up libgail18:amd64 (2.24.32-1ubuntu1) ...
# Setting up cuda-driver-dev-9-2 (9.2.88-1) ...
# Setting up cuda-curand-9-2 (9.2.88-1) ...
# Setting up cuda-cusolver-dev-9-2 (9.2.88-1) ...
# Setting up libxmu-dev:amd64 (2:1.1.2-2) ...
# Setting up libpolkit-agent-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Setting up default-jre (2:1.11-68ubuntu1~18.04.1) ...
# Setting up cuda-nsight-9-2 (9.2.88-1) ...
# Setting up cuda-cublas-9-2 (9.2.88-1) ...
# Setting up cuda-cuobjdump-9-2 (9.2.88-1) ...
# Setting up x11-utils (7.7+3build1) ...
# Setting up cuda-cusparse-9-2 (9.2.88-1) ...
# Setting up libxfont2:amd64 (1:2.0.3-1) ...
# Setting up cuda-nvgraph-9-2 (9.2.88-1) ...
# Setting up xfonts-utils (1:7.7+6) ...
# Setting up libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Setting up cuda-gpu-library-advisor-9-2 (9.2.88-1) ...
# Setting up fakeroot (1.22-2ubuntu1) ...
# update-alternatives: using /usr/bin/fakeroot-sysv to provide /usr/bin/fakeroot (fakeroot) in auto mode
# Setting up cuda-gdb-9-2 (9.2.88-1) ...
# Setting up libpolkit-backend-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Setting up cuda-cudart-dev-9-2 (9.2.88-1) ...
# Setting up cuda-cufft-dev-9-2 (9.2.88-1) ...
# Setting up libnvidia-gl-450:amd64 (450.57-0ubuntu0~0.18.04.2) ...
# Setting up cuda-libraries-9-2 (9.2.88-1) ...
# Setting up cuda-cusparse-dev-9-2 (9.2.88-1) ...
# Setting up cuda-nvcc-9-2 (9.2.88-1) ...
# Setting up libatk-wrapper-java (0.33.3-20ubuntu0.1) ...
# Setting up xserver-xorg-core-hwe-18.04 (2:1.20.8-2ubuntu2.2~18.04.1) ...
# Setting up cuda-cupti-9-2 (9.2.88-1) ...
# Setting up cuda-cublas-dev-9-2 (9.2.88-1) ...
# Setting up xfonts-base (1:1.0.4+nmu1) ...
# Setting up xserver-xorg-video-nvidia-450 (450.57-0ubuntu0~0.18.04.2) ...
# Setting up cuda-nvgraph-dev-9-2 (9.2.88-1) ...
# Setting up libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Setting up libnvidia-ifr1-450:amd64 (450.57-0ubuntu0~0.18.04.2) ...
# Setting up cuda-command-line-tools-9-2 (9.2.88-1) ...
# Setting up cuda-curand-dev-9-2 (9.2.88-1) ...
# Setting up cuda-nvvp-9-2 (9.2.88-1) ...
# Setting up policykit-1 (0.105-20ubuntu0.18.04.5) ...
# Setting up cuda-visual-tools-9-2 (9.2.88-1) ...
# Setting up cuda-compiler-9-2 (9.2.88-1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.33.3-20ubuntu0.1) ...
# Setting up policykit-1-gnome (0.105-6ubuntu2) ...
# Setting up screen-resolution-extra (0.17.3) ...
# Setting up nvidia-driver-450 (450.57-0ubuntu0~0.18.04.2) ...
# Setting up cuda-libraries-dev-9-2 (9.2.88-1) ...
# Setting up cuda-samples-9-2 (9.2.88-1) ...
# Setting up cuda-documentation-9-2 (9.2.88-1) ...
# Setting up cuda-tools-9-2 (9.2.88-1) ...
# Setting up cuda-toolkit-9-2 (9.2.88-1) ...
# Setting up nvidia-settings (450.51.06-0ubuntu1) ...
# Setting up cuda-drivers-450 (450.51.06-1) ...
# Setting up cuda-drivers (450.51.06-1) ...
# Setting up cuda-runtime-9-2 (9.2.88-1) ...
# Setting up cuda-demo-suite-9-2 (9.2.88-1) ...
# Setting up cuda-9-2 (9.2.88-1) ...
# Processing triggers for systemd (237-3ubuntu10.42) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for dbus (1.12.2-1ubuntu1.2) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link

# %%
# !nvcc --version

# %%
# !pip install git+git://github.com/andreinechaev/nvcc4jupyter.git

# %%
# %load_ext nvcc_plugin

# %% [markdown]
# #**Introduction**
#
# C++ (pronounced see plus plus) is a general purpose programming language that is free-form and compiled. It is regarded as an intermediate-level language, as it comprises both high-level and low-level language features. It provides imperative, object-oriented and generic programming features.
#
# C++ is one of the most popular programming languages and is implemented on a wide variety of hardware and operating system platforms. As an efficient performance driven programming language it is used in systems software, application software, device drivers, embedded software, high-performance server and client applications, and entertainment software such as video games. Various entities provide both open source and proprietary C++ compiler software, including the FSF, LLVM, Microsoft and Intel.

# %% [markdown]
# #1- **Hellow Words**
# Every C++ program uses libraries, which give the ability to execute necessary functions. For example, the most basic function called 'cout', which prints to the screen, is defined in the iostream header file.
#
# To add the ability to run the cout command to our program, we must add following include directive to our first line of the code:

# %%
# %%cu
# #include <iostream>
# using namespace std;
#
# int main() {
#   cout << "Goodbye, World!" << std::endl;
#   return 0;
# }

# %% [markdown]
# #2-**Variable and types**
#
# **Data types**
#
# C++ provides a rich set of built-in as well as user defined data types. Following table lists down seven basic C++ data types:
#
# **Built-in**
# - Boolean - boolean - either true or false
# - Integers - whole numbers which can be both positive and negative. Defined using char, int.
# - Floating point numbers - real numbers (numbers with - fractions). Defined using float and double.
# Valueless using the void keyword
# Wide character using the wchar_t keyword

# %% [markdown]
# #**References**
# How to Run CUDA C or C++ on Jupyter (Google Colab)
# https://www.wikihow.com/Run-CUDA-C-or-C%2B%2B-on-Jupyter-(Google-Colab)
#
# Welcome
# https://www.learn-cpp.org/
